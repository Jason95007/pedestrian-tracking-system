# %%
# 1.安裝 YOLOv8 函式庫
# !pip install ultralytics -q

# 2.匯入必要的模組
import ultralytics
from ultralytics import YOLO
import cv2
import os
from google.colab import files
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 27.1 MB/s eta 0:00:00

# %%
# 3.上傳影片
uploaded = files.upload()
video_path = next(iter(uploaded))   # 取得上傳影片的路徑
print(f"🎬 已上傳影片：{video_path}")

# 4.載入YOLOv8模型
model = YOLO('yolov8n.pt')
print("✅ YOLOv8 模型載入完成")
# 5.執行影片追蹤與偵測
output_video_path = 'output_person_tracking.avi'# 輸出影片的路徑
project_dir = "runs/track"
name = "video_analysis"

# 追蹤結果會儲存在 'runs/track/video_analysis/'
print(f"追蹤結果已儲存至 'runs/track/video_analysis/' 資料夾。")

# 4.載入YOLOv8模型
model = YOLO('yolov8n.pt')
print("✅ YOLOv8 模型載入完成")
# 5.執行影片追蹤與偵測
output_video_path = 'output_person_tracking.avi'# 輸出影片的路徑
project_dir = "runs/track"
name = "video_analysis"

# 設置追蹤器
# YOLOv8預設內建了一些追蹤器
results = model.track(
      source=video_path,
      tracker="bytetrack.yaml",  # 使用 ByteTrack 追蹤器
      save=True,                 # 儲存標註影片
      project=project_dir,
      name=name,
      conf=0.4,                  # 偵測信心度門檻
      classes=[0],                # 只偵測人（class id = 0）
      show_labels=False,         # 不顯示標籤文字（例如 "person"）
      show_conf=False,         # 不顯示信心度數字
      line_thickness=1
)

# 追蹤結果會儲存在 'runs/track/video_analysis/'
print(f"追蹤結果已儲存至 'runs/track/video_analysis/' 資料夾。")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
#      <input type="file" id="files-49c79f75-7fd6-4f5c-8b77-8442d9799ed1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-49c79f75-7fd6-4f5c-8b77-8442d9799ed1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# ...
